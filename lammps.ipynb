# %%
from pyiron_atomistics import Project

# %%
pr = Project("test")

# %%
job = pr.create.job.Lammps("lmp")

# %%
job.structure = pr.create.structure.ase.bulk("Al", cubic=True)

# %%
job.enable_h5md()

# %%
job.run()
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyiron_atomistics/lammps/base.py:240: UserWarning: No potential set via job.potential - use default potential, 1995--Angelo-J-E--Ni-Al-H--LAMMPS--ipr1
#   warnings.warn("No potential set via job.potential - use default potential, " + lst_of_potentials[0])
# 2021-08-25 04:23:11,640 - pyiron_log - WARNING - Job aborted
# 2021-08-25 04:23:11,642 - pyiron_log - WARNING - LAMMPS (30 Jul 2021)
# Reading data file ...
#   orthogonal box = (0.0000000 0.0000000 0.0000000) to (4.0500000 4.0500000 4.0500000)
#   1 by 1 by 1 MPI processor grid
#   reading atoms ...
#   4 atoms
#   read_data CPU = 0.001 seconds
# ERROR: Unrecognized dump style 'h5md' is part of the H5MD package which is not enabled in this LAMMPS binary. (src/output.cpp:570)
# Last command: dump 1 all h5md ${dumptime} dump.h5 position force create_group yes
# The job lmp was saved and received the ID: 1
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyiron_base/job/generic.py in run_static(self)
#     728                     stderr=subprocess.STDOUT,
# --> 729                     universal_newlines=True,
#     730                 )
#
# /srv/conda/envs/notebook/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#
# /srv/conda/envs/notebook/lib/python3.7/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     511             raise CalledProcessError(retcode, process.args,
# --> 512                                      output=stdout, stderr=stderr)
#     513     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '/srv/conda/envs/notebook/share/pyiron/lammps/bin/run_lammps_2020.03.03.sh' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-547a87b2509b> in <module>
# ----> 1 job.run()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyiron_base/generic/util.py in decorated(*args, **kwargs)
#     211                         stacklevel=2
#     212                     )
# --> 213             return function(*args, **kwargs)
#     214         return decorated
#     215
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyiron_base/job/generic.py in run(self, delete_existing_job, repair, debug, run_mode, run_again)
#     672                 self._run_if_repair()
#     673             elif status == "initialized":
# --> 674                 self._run_if_new(debug=debug)
#     675             elif status == "created":
#     676                 self._run_if_created()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyiron_base/job/generic.py in _run_if_new(self, debug)
#    1321         else:
#    1322             self.save()
# -> 1323             self.run()
#    1324
#    1325     def _run_if_created(self):
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyiron_base/generic/util.py in decorated(*args, **kwargs)
#     211                         stacklevel=2
#     212                     )
# --> 213             return function(*args, **kwargs)
#     214         return decorated
#     215
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyiron_base/job/generic.py in run(self, delete_existing_job, repair, debug, run_mode, run_again)
#     674                 self._run_if_new(debug=debug)
#     675             elif status == "created":
# --> 676                 self._run_if_created()
#     677             elif status == "submitted":
#     678                 self._run_if_submitted()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyiron_base/job/generic.py in _run_if_created(self)
#    1338             self.run_if_manually()
#    1339         elif self.server.run_mode.modal:
# -> 1340             self.run_static()
#    1341         elif self.server.run_mode.non_modal or self.server.run_mode.thread:
#    1342             self.run_if_non_modal()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pyiron_base/job/generic.py in run_static(self)
#     760                 if self.server.run_mode.non_modal:
#     761                     s.close_connection()
# --> 762                 raise RuntimeError("Job aborted")
#     763             else:
#     764                 job_crashed = True
#
# RuntimeError: Job aborted
